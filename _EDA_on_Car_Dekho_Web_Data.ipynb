# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/CAR DETAILS FROM CAR DEKHO.csv")

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
dataset.shape
# Out:
# (4340, 8)

# %%
dataset.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# # Data Cleaning

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
dataset.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# "We found that our dataset contains no null values and also provides a relevant summary with 8 numerical variables."

# %%
dataset.sample(5)
# Out:
#                                           name  year  selling_price  \
# 93               Mahindra Bolero 2011-2019 SLE  2013         325000
# 902                        Maruti SX4 Vxi BSIV  2012         225000
# 3998                  Tata Indigo Grand Petrol  2014         240000
# 2237  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 3743                    Maruti Swift Dzire VDI  2015         470000
#
#       km_driven    fuel seller_type transmission         owner
# 93        62200  Diesel      Dealer       Manual   First Owner
# 902      110000  Petrol  Individual       Manual  Second Owner
# 3998      60000  Petrol  Individual       Manual  Second Owner
# 2237      10000  Diesel      Dealer    Automatic   First Owner
# 3743      89000  Diesel  Individual       Manual   First Owner

# %% [markdown]
# We have 3 columns with integer values and 5 columns with string values.

# %%
dataset.duplicated().sum()

# "It is acceptable to have duplicate values in the dataset."
# Out:
# 763

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# *univariate* *analysis*

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
dataset["name"].unique().shape

# "We have data of "1491" cars."
# Out:
# (1491,)

# %%
dataset["name"]
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
df1  = dataset["name"].value_counts()

df2 = df1.reset_index()

df2
# Out:
#                                          name  count
# 0                      Maruti Swift Dzire VDI     69
# 1                         Maruti Alto 800 LXI     59
# 2                             Maruti Alto LXi     47
# 3                              Maruti Alto LX     35
# 4                        Hyundai EON Era Plus     35
# ...                                       ...    ...
# 1486  Hyundai Verna Transform CRDi VGT SX ABS      1
# 1487                 Maruti S-Presso VXI Plus      1
# 1488                 Toyota Etios Liva 1.2 VX      1
# 1489                           Toyota Yaris G      1
# 1490               Hyundai i20 Magna 1.4 CRDi      1
#
# [1491 rows x 2 columns]

# %%
df2.head(1)

# since the most selling car company is Maruti
#  most selling model -  Maruti Swift Dzire VDI
#  selling model qunatity = 69
# Out:
#                      name  count
# 0  Maruti Swift Dzire VDI     69

# %%
df3 = df2.head(5)
plt.figure(figsize=(18,10))
plt.bar(df3["name"],df3["count"])
# Out:
# <BarContainer object of 5 artists>

# %%
#  top 5 selleing cars are

# 1 Maruti Swift Dzire VDI
# 2	Maruti Alto 800 LXI
# 3	Maruti Alto LXi
# 4	Maruti Alto LX
# 5	Hyundai EON Era Plus

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
plt.figure(figsize=(20,12))

plt.hist(dataset["year"], bins = [1996,1997,1998,1999,2000,2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
])
plt.xticks(range(1996 , 2022 , 2))
plt.xlabel("year")
# Out:
# Text(0.5, 0, 'year')

# %%
# "Since 2018, the most cars have been sold in India."

# %%
df4 = dataset[dataset["year"] == 2018]
df4["name"].value_counts()
# Out:
# name
# Mercedes-Benz C-Class Progressive C 220d    11
# Maruti Alto 800 LXI                         10
# Hyundai EON Magna Plus                       9
# Renault KWID 1.0 RXT Optional                8
# Maruti Swift Dzire VDI                       6
#                                             ..
# Hyundai Verna VTVT 1.6 SX                    1
# Hyundai Xcent 1.2 VTVT S                     1
# Volkswagen Ameo 1.2 MPI Trendline            1
# Mahindra XUV500 W7                           1
# Mahindra TUV 300 Plus P4                     1
# Name: count, Length: 220, dtype: int64

# %%
# "Since 2018, the Mercedes-Benz C-Class Progressive C 220d has been the best-selling car, with 11 units sold that year."

# %%
dataset[dataset["name"] == "Mercedes-Benz C-Class Progressive C 220d" ]

# "All Mercedes-Benz C-Class Progressive C 220d cars were newly purchased; none were second-hand."
# Out:
#                                           name  year  selling_price  \
# 553   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 572   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 591   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 610   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 898   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 917   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 1021  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 1834  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 2237  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 2256  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 2737  Mercedes-Benz C-Class Progressive C 220d  2018        3800000
#
#       km_driven    fuel seller_type transmission        owner
# 553       10000  Diesel      Dealer    Automatic  First Owner
# ...

# %%
df4[df4["fuel"] == "Diesel"]
# Out:
#                                     name  year  selling_price  km_driven  \
# 31     Maruti Vitara Brezza ZDi Plus AMT  2018         975000       4500
# 56           Hyundai i20 Sportz 1.4 CRDi  2018         750000      29000
# 78                 Maruti Ciaz 1.3 Delta  2018         750000      60000
# 103                Volvo V40 D3 R Design  2018        1975000      21000
# 109                     Mahindra Xylo D4  2018         750000      87000
# ...                                  ...   ...            ...        ...
# 4236     Hyundai Grand i10 1.2 CRDi Asta  2018         465000      25000
# 4254        Hyundai Verna CRDi 1.6 AT EX  2018        1100000      25000
# 4256     Hyundai Grand i10 1.2 CRDi Asta  2018         465000      25000
# 4274        Hyundai Verna CRDi 1.6 AT EX  2018        1100000      25000
# 4304  Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
#
#         fuel seller_type transmission         owner
# ...

# %%
print(366 - 167)
#  in 2018 petrol car selled more - 199 unit * - price bhi nikl lena
# Out:
# 199

# %%
plt.figure(figsize=(20,12))
plt.scatter(dataset["selling_price"], dataset["km_driven"])
# their be no correaltion b/w selling price and km_driven cols.

# %%
sns.displot(data  = dataset , x = "selling_price", kde = True)

# "The selling price column is highly left-skewed, indicating that many cars have very low prices compared to a few cars (which have a much higher price).

# %%
dataset["selling_price"].describe()
# Out:
# count    4.340000e+03
# mean     5.041273e+05
# std      5.785487e+05
# min      2.000000e+04
# 25%      2.087498e+05
# 50%      3.500000e+05
# 75%      6.000000e+05
# max      8.900000e+06
# Name: selling_price, dtype: float64

# %%
dataset["selling_price"].max()
# Out:
# 8900000

# %%
dataset["selling_price"].mean()

# avg selleing prize of car
# 504127.3117511521
# Out:
# 504127.3117511521

# %%
dataset["selling_price"].min()
# Out:
# 20000

# %%
dataset[dataset["selling_price"] == 20000]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner
# 2662  Individual       Manual  Second Owner

# %%
df6 = dataset[dataset["owner"] == "First Owner"]
df6["selling_price"].mean()
# Out:
# 598636.9696327683

# %%
df6["selling_price"].describe()
# Out:
# count    2.832000e+03
# mean     5.986370e+05
# std      6.544989e+05
# min      4.000000e+04
# 25%      2.600000e+05
# 50%      4.500000e+05
# 75%      6.850000e+05
# max      8.900000e+06
# Name: selling_price, dtype: float64

# %%
sns.displot(data  = df6 , x = "selling_price", kde = True)

# %%
df6[df6["selling_price"]== 40000]
#  their are cars who's price are 40k -Tata Nano Std - 2011 , Maruti 800 EX  , Tata Nano Lx
# Out:
#                name  year  selling_price  km_driven    fuel seller_type  \
# 877   Tata Nano Std  2011          40000      19000  Petrol  Individual
# 1350  Maruti 800 EX  2001          40000      30000  Petrol  Individual
# 2730   Tata Nano Lx  2010          40000      90000  Petrol  Individual
#
#      transmission        owner
# 877        Manual  First Owner
# 1350       Manual  First Owner
# 2730       Manual  First Owner

# %%
df6[df6["name"]== "Tata Nano Lx"]
# Out:
#               name  year  selling_price  km_driven    fuel seller_type  \
# 442   Tata Nano Lx  2011          75000      15000  Petrol  Individual
# 831   Tata Nano Lx  2011         120000      20000  Petrol  Individual
# 832   Tata Nano Lx  2011         120000      20000  Petrol  Individual
# 1009  Tata Nano Lx  2011         120000      20000  Petrol  Individual
# 1014  Tata Nano Lx  2011         120000      20000  Petrol  Individual
# 1213  Tata Nano Lx  2011          60000      40000  Petrol  Individual
# 2730  Tata Nano Lx  2010          40000      90000  Petrol  Individual
#
#      transmission        owner
# 442        Manual  First Owner
# 831        Manual  First Owner
# 832        Manual  First Owner
# 1009       Manual  First Owner
# 1014       Manual  First Owner
# 1213       Manual  First Owner
# 2730       Manual  First Owner

# %%
df7 = dataset[dataset["owner"] == "Second Owner"]
df7["selling_price"].describe()
# Out:
# count    1.106000e+03
# mean     3.438911e+05
# std      3.459784e+05
# min      2.000000e+04
# 25%      1.500000e+05
# 50%      2.504995e+05
# 75%      4.300000e+05
# max      4.400000e+06
# Name: selling_price, dtype: float64

# %%
# second person

df7["selling_price"].min()

c
# Out:
# 20000

# %%
# second person
df7[df7["selling_price"] == 4400000]

#  peope buy Mercedes-Benz GL-Class 350 CDI Blue Efficiency in 440000 , where as Mercedes-Benz GL-Class 350 CDI Blue Efficiency price in first ower is 8900000
# Out:
#                                                 name  year  selling_price  \
# 539   Mercedes-Benz GL-Class 350 CDI Blue Efficiency  2014        4400000
# 2178  Mercedes-Benz GL-Class 350 CDI Blue Efficiency  2014        4400000
#
#       km_driven    fuel seller_type transmission         owner
# 539      100000  Diesel  Individual    Automatic  Second Owner
# 2178     100000  Diesel  Individual    Automatic  Second Owner

# %%
df6["km_driven"].max()
# Out:
# 806599

# %%
df6[df6["km_driven"]== 806599]
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 1243  Maruti Swift VXI BSIII  2009         250000     806599  Petrol
#
#      seller_type transmission        owner
# 1243      Dealer       Manual  First Owner

# %%
df6["km_driven"].min()
# Out:
# 1000

# %%
df8 = df6[df6["km_driven"]== 1000]

# %%
df6["selling_price"].mean()
# Out:
# 598636.9696327683

# %%
df9 = dataset["fuel"].value_counts()
#  fuel col. have 5 categoary - Diesel ,Petrol , CNG , LPG , Electric

# %%
 df10 = df9.reset_index()
 df10
# Out:
#        fuel  count
# 0    Diesel   2153
# 1    Petrol   2123
# 2       CNG     40
# 3       LPG     23
# 4  Electric      1

# %%
plt.figure(figsize=(8,6))
plt.bar(df10["fuel"], df10["count"])
# Out:
# <BarContainer object of 5 artists>

# %%
t = dataset[dataset["fuel"] == "Petrol"]
t["selling_price"].mean()

# avg - price of petrol cars is 344840.1
# Out:
# 344840.1375412153

# %%
t = dataset[dataset["fuel"] == "Diesel"]
t["selling_price"].mean()

# avg - price of diesel cars is 669094.25
# Out:
# 669094.2522062239

# %%
t = dataset[dataset["fuel"] == "CNG"]
t
# Out:
#                                         name  year  selling_price  km_driven  \
# 9                   Maruti Celerio Green VXI  2017         365000      78000
# 22                  Maruti Celerio Green VXI  2017         365000      78000
# 176                  Maruti Alto K10 LXI CNG  2020         282000      40000
# 351              Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352   Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
# 361              Hyundai Santro Xing GLS CNG  2010         130000      98000
# 664          Hyundai Santro Xing GL PLUS CNG  2007          90000      80000
# 712                    Maruti Ertiga VXI CNG  2013         525000      56228
# 824                  Maruti Alto 800 CNG LXI  2012         170000      97000
# 863                   Hyundai Accent GLE CNG  2009         160000      70000
# 1138                  Maruti Wagon R LXI CNG  2013         250000      71000
# ...

# %%
t["selling_price"].mean()

# Avg price of CNG car
277174.925
# Out:
# 277174.925

# %%
t["selling_price"].sum()

# some tatal revenue of CNG
# Out:
# 11086997

# %%
dataset["selling_price"].sum()

#  total revenue
# Out:
# 2187912533

# %%
t = dataset[dataset["fuel"] == "LPG"]
t
# Out:
#                                            name  year  selling_price  \
# 157                      Maruti Wagon R DUO LPG  2014         210000
# 222   Maruti Omni LPG CARGO BSIII W IMMOBILISER  2009          80000
# 483                  Hyundai EON LPG Magna Plus  2012         180000
# 495           Hyundai Santro Xing GLS Audio LPG  2012         250000
# 657                       Hyundai i10 Magna LPG  2013         250000
# 703             Hyundai Santro Xing GL Plus LPG  2011         229999
# 1355                Maruti Wagon R LXI LPG BSIV  2012         220000
# 1435                      Hyundai i10 Magna LPG  2014         290000
# 1670               Maruti Wagon R LXI DUO BS IV  2012         180000
# 1699                  Maruti Omni 5 Str STD LPG  1998          50000
# 1702                      Maruti 800 DUO AC LPG  2009          85000
# 1810               Maruti Wagon R LXI DUO BSIII  2009         155000
# 1942               Maruti Wagon R LXI DUO BSIII  2008         125000
# ...

# %%
t["selling_price"].sum()
# Out:
# 3859999

# %%
t["selling_price"].mean()

# avg  price of LPG car
167826.04
# Out:
# 167826.04347826086

# %%
t = dataset[dataset["fuel"] == "Electric"]
t
# Out:
#                      name  year  selling_price  km_driven      fuel  \
# 4145  Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner
# 4145      Dealer    Automatic  Second Owner

# %%
s = dataset["seller_type"].value_counts()
s

# their be 3 categary of seller we have
    # Individual
    # Dealer
    # Trustmark Dealer
#  In INDIA people prefer to buy cars from Individual  seller as comapared to other 2 categary
    # Individual        -  3244 selled units
    # Dealer            -  994  selled units
    # Trustmark Dealer  -  102  selled units
#  people in INDAI prefer to buy First OWNER car from Individual seller type
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
k = s.reset_index()
k
plt.bar(k["seller_type"], k["count"])
# Out:
# <BarContainer object of 3 artists>

# %%
s = dataset[dataset["seller_type"] == "Individual"]
s
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
s[s["owner"] == "First Owner"].shape
# Out:
# (1890, 8)

# %%
s[s["owner"] == "Second Owner"].shape
# Out:
# (980, 8)

# %%
s = dataset[dataset["seller_type"] == "Dealer"]
s
# Out:
#                                     name  year  selling_price  km_driven  \
# 12       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 26                  Maruti Ciaz VXi Plus  2015         585000      24000
# 27           Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 29            Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# ...                                  ...   ...            ...        ...
# 4304  Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4306              Hyundai i10 Sportz 1.2  2011         235000      43100
# 4309                    Datsun GO Plus T  2017         350000      10171
# 4310     Renault Duster 110PS Diesel RxL  2015         465000      41123
# 4311             Toyota Camry Hybrid 2.5  2017        1900000      20118
#
#         fuel seller_type transmission        owner
# ...

# %%
s[s["owner"] == "First Owner"].shape
# Out:
# (844, 8)

# %%
s[s["owner"] == "Second Owner"].shape
# Out:
# (122, 8)

# %%
s = dataset[dataset["seller_type"] == "Trustmark Dealer"]
s
# Out:
#                                  name  year  selling_price  km_driven    fuel  \
# 540             Maruti Swift ZXI BSIV  2016         670000       7104  Petrol
# 541   Maruti S-Cross Zeta DDiS 200 SH  2015         750000      45974  Diesel
# 542         Hyundai Verna 1.6 VTVT SX  2015         760000      55340  Petrol
# 544                 Renault Pulse RxL  2015         390000      61585  Diesel
# 545       Maruti Celerio VXI AMT BSIV  2016         450000      39415  Petrol
# ...                               ...   ...            ...        ...     ...
# 4096   Mahindra XUV500 W10 1.99 mHawk  2016        1250000      23670  Diesel
# 4097           Maruti Baleno Zeta 1.2  2017         650000      49834  Petrol
# 4098                  Honda Brio S MT  2013         295000      57353  Petrol
# 4099            Maruti Swift DDiS VDI  2015         480000      68308  Diesel
# 4100             Honda City i DTEC SV  2015         575000      63240  Diesel
#
# ...

# %%
s[s["owner"] == "First Owner"].shape
# Out:
# (98, 8)

# %%
s[s["owner"] == "Second Owner"].shape
# Out:
# (4, 8)

# %%
s = dataset["transmission"].value_counts()
s
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
k = s.reset_index()
plt.bar(k["transmission"] , k["count"])
# Out:
# <BarContainer object of 2 artists>

# %%
s = dataset[dataset["transmission"] == "Manual"]
s
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
s[s["owner"] == "First Owner"].shape
# Out:
# (2483, 8)

# %%
s[s["owner"] == "Second Owner"].shape

#  people like to buy manual car - first hand more
# Out:
# (1031, 8)

# %%
s = dataset[dataset["transmission"] == "Automatic"]
s
# Out:
#                                          name  year  selling_price  km_driven  \
# 12            Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25            Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 29                 Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# 30       Mercedes-Benz New C-Class 220 CDI AT  2013        1425000      59000
# 31          Maruti Vitara Brezza ZDi Plus AMT  2018         975000       4500
# ...                                       ...   ...            ...        ...
# 4300  Mercedes-Benz E-Class E250 CDI Elegance  2011         999000      49600
# 4302                       BMW 7 Series 730Ld  2006        1050000      30000
# 4304       Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4311                  Toyota Camry Hybrid 2.5  2017        1900000      20118
# 4313       Ford Endeavour 2.2 Titanium AT 4X2  2019        2800000      10000
#
# ...

# %%
s[s["owner"] == "First Owner"].shape
# Out:
# (349, 8)

# %%
s[s["owner"] == "Second Owner"].shape
# Out:
# (75, 8)

# %%
s = dataset["owner"].value_counts()

# %%
k = s.reset_index()
k
# Out:
#                   owner  count
# 0           First Owner   2832
# 1          Second Owner   1106
# 2           Third Owner    304
# 3  Fourth & Above Owner     81
# 4        Test Drive Car     17

# %%
plt.bar(k["owner"],k["count"])
plt.xticks(rotation = 90)

# sns.catplot(x = "owner" , y = "count" , data = k, kind = "bar", )
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'First Owner'),
#   Text(1, 0, 'Second Owner'),
#   Text(2, 0, 'Third Owner'),
#   Text(3, 0, 'Fourth & Above Owner'),
#   Text(4, 0, 'Test Drive Car')])

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# # **Conculsion**
#
# # 1. "We have data of "1491" cars."
#
# # 2. Maruti is the best-selling car company
#       -> Maruti Swift Dzire VDI is the best-selling model."
#       ->the quantity of the selling model is - 69 units
#
# # 3. Top 5 selleing cars are
#
#     1 Maruti Swift Dzire VDI
#     2	Maruti Alto 800 LXI
#     3	Maruti Alto LXi
#     4	Maruti Alto LX
#     5	Hyundai EON Era Plus
#
#
# # 4. People tend to prefer buying manual cars as first-hand purchases.
#
# # 5. AVG PRICE
#     avg - price of diesel cars is 669094.25
#     avg - price of petrol cars is 344840.1
#     avg - price of CNG car is 277174.92
#     avg - price of LPG car is 167826.04
#
#
# # 6. their be 3 categary of seller we have
#      Individual
#      Dealer
#      Trustmark Dealer
#
#
#    ** -> In INDIA people prefer to buy cars from Individual  seller as comapared to other 2 categary **
#
#      Individual        -  3244 sold units
#      Dealer            -  994  sold units
#      Trustmark Dealer  -  102  sold units
#
#
# # 7. people in INDAI prefer to buy First OWNER car from Individual seller type
#
#
# # 8. fuel col. have 5 categoary - Diesel ,Petrol , CNG , LPG , Electric
#       -> **Units selled**
#     	Diesel	  2153
#     	Petrol	  2123
#     	CNG	      40
#     	LPG	      23
#     	Electric	 1
#
#
# # 9. 2018, the most cars have been sold in India.
#
#     -> the Mercedes-Benz C-Class Progressive C 220d has been the best-selling car, with 11 units sold that year."
#
#     -> "All Mercedes-Benz C-Class Progressive C 220d cars were newly purchased; none were second-hand."
#
#     -> in 2018 petrol car selled more - 199 unit * - price bhi nikl lena
#
# # 10.  The selling price column is highly left-skewed, indicating that many cars have very low prices compared to a few cars (which have a much higher price).
#     avg selleing prize of car
#     504127.3117511521
#
#     -> their are cars who's price are 40k
#            Tata Nano Std - 2011
#            Maruti 800 EX
#            Tata Nano Lx
#
#     ->  peope buy Mercedes-Benz GL-Class 350 CDI Blue Efficiency in 440000 , where as Mercedes-Benz GL-Class 350 CDI Blue Efficiency price in first ower is 8900000

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...
